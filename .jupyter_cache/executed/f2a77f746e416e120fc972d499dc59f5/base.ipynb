miniconda3/lib/python3.13/operator.py": 1765402968.181258, "/home/gongcastro/miniconda3/lib/python3.13/reprlib.py": 1765402968.2332582, "/home/gongcastro/miniconda3/lib/python3.13/collections/__init__.py": 1765402968.4362593, "/home/gongcastro/miniconda3/lib/python3.13/functools.py": 1765402968.1142576, "/home/gongcastro/miniconda3/lib/python3.13/contextlib.py": 1765402968.0722575, "/home/gongcastro/miniconda3/lib/python3.13/enum.py": 1765402968.0992575, "/home/gongcastro/miniconda3/lib/python3.13/re/_constants.py": 1765402969.3232641, "/home/gongcastro/miniconda3/lib/python3.13/re/_parser.py": 1765402969.325264, "/home/gongcastro/miniconda3/lib/python3.13/re/_casefix.py": 1765402969.317264, "/home/gongcastro/miniconda3/lib/python3.13/re/_compiler.py": 1765402969.320264, "/home/gongcastro/miniconda3/lib/python3.13/copyreg.py": 1765402968.0802574, "/home/gongcastro/miniconda3/lib/python3.13/re/__init__.py": 1765402969.315264, "/home/gongcastro/miniconda3/lib/python3.13/fnmatch.py": 1765402968.1062577, "/home/gongcastro/miniconda3/lib/python3.13/glob.py": 1765402968.1262577, "/home/gongcastro/miniconda3/lib/python3.13/pathlib/_abc.py": 1765402969.299264, "/home/gongcastro/miniconda3/lib/python3.13/ntpath.py": 1765402968.171258, "/home/gongcastro/miniconda3/lib/python3.13/warnings.py": 1765402968.3352587, "/home/gongcastro/miniconda3/lib/python3.13/lib-dynload/grp.cpython-313-x86_64-linux-gnu.so": 1765402981.0593266, "/home/gongcastro/miniconda3/lib/python3.13/pathlib/_local.py": 1765402969.302264, "/home/gongcastro/miniconda3/lib/python3.13/pathlib/__init__.py": 1765402969.2972639, "/home/gongcastro/Documents/Presentations/uoc-2026-fnirs/.venv/lib/ ...

# %%
#| label: setup
from pathlib import Path

from matplotlib import pyplot as plt
from matplotlib import colors
import numpy as np
import pandas as pd

from cedalion.dataclasses import Recording

from src import nirs

plt.rcParams["figure.autolayout"] = True

MOP_STIM_MAPPING = {
    "A": [6, 7, 8, 9, 18, 19, 20, 21],
    "B": [10, 11, 12, 13, 22, 23, 24, 25],
    "C": [14, 15, 16, 17, 26, 27, 28, 29],
}

SSP_STIM_MAPPING: dict[str, list[int]] = {
    "A": [9],
    "B": [10],
    "Exclude": [4, 6, 7],
}

CHROMO_COLORS = {760: "tab:blue", 850: "tab:red", "HbR": "tab:blue", "HbO": "tab:red"}
COND_COLORS = {"A": "tab:blue", "B": "tab:orange", "C": "tab:green"}
